# %%
# Try to load CyberGIS-Compute client
# try:
#     from cybergis_compute_client import CyberGISCompute
# # If not already setup, setup CyberGIS-Compute in the current Jupyter kernel
# except:
import sys
# !{sys.executable} -m pip install --ignore-installed git+https://github.com/cybergis/job-supervisor-python-sdk.git@v2
# Out:
# ...
#   Cloning https://github.com/cybergis/job-supervisor-python-sdk.git (to revision v2) to /tmp/pip-req-build-lv3h8mtp
#   Running command git clone --filter=blob:none --quiet https://github.com/cybergis/job-supervisor-python-sdk.git /tmp/pip-req-build-lv3h8mtp
#   Resolved https://github.com/cybergis/job-supervisor-python-sdk.git to commit 11c5c6fd2a00e75e274bc1d6f965c9252e736dd9
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 399.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 363.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.5/381.5 kB 507.9 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 694.6 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 650.0 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 881.4 kB/s eta 0:00:0000:0100:01
# ...

# %%
from cybergis_compute_client import CyberGISCompute

cybergis = CyberGISCompute(url="172.27.0.4", protocol="HTTP", port=3030, isJupyter=True)

# %%
cybergis.jupyterhubHost = "172.27.0.3:443"
print(cybergis.jupyterhubHost)
# Out:
# 172.27.0.3:443

# %%
# !printenv | grep "JUPYTERHUB_API_TOKEN"
# Out:
# JUPYTERHUB_API_TOKEN=8846b85edc1448aa9613e3e9e91725ae

# %%
cybergis.jupyterhubApiToken = "8846b85edc1448aa9613e3e9e91725ae"  # get yours from CyberGISX in the terminal you can use "printenv | grep "JUPYTERHUB_API_TOKEN""
print(cybergis.jupyterhubApiToken)
# Out:
# 8846b85edc1448aa9613e3e9e91725ae

# %%
cybergis.login()
# Out:
# 💻 Found system token
# 🎯 Logged in as admin@172.27.0.3:443

# %%
cybergis.__dict__
# Out:
# {'client': <cybergis_compute_client.Client.Client at 0x7f68274eb310>,
#  'jupyterhubApiToken': 'MTcyLjI3LjAuMzo0NDNAODg0NmI4NWVkYzE0NDhhYTk2MTNlM2U5ZTkxNzI1YWU=',
#  'username': 'admin@172.27.0.3:443',
#  'isJupyter': True,
#  'ui': <cybergis_compute_client.UI.UI at 0x7f68274ea8c0>,
#  'job': None,
#  'recentDownloadPath': None,
#  'jupyterhubHost': '172.27.0.3:443'}

# %%
cybergis.username = "admin@172.27.0.3:443"

# %%
job = cybergis.create_job(hpc="local_hpc",hpcUsername="user",hpcPassword="newpass")
# Out:
# 🎯 Logged in as admin@172.27.0.3:443
# ⚠️ HPC password input detected, change your code to use .get_job_by_id() instead
# 🙅‍♂️ it's not safe to distribute code with login credentials
# <table>
# <thead>
# <tr><th style="text-align:left">id             </th><th style="text-align:left">slurmId  </th><th style="text-align:left">hpc      </th><th style="text-align:left">executableFolder  </th><th style="text-align:left">dataFolder  </th><th style="text-align:left">resultFolder  </th><th style="text-align:left">param  </th><th style="text-align:left">slurm  </th><th style="text-align:left">userId              </th><th style="text-align:left">maintainer            </th><th style="text-align:left">createdAt               </th></tr>
# </thead>
# <tbody>
# ...

# %%
job.__dict__
# Out:
# {'JAT': <cybergis_compute_client.JAT.JAT at 0x7f68274e9a80>,
#  'client': <cybergis_compute_client.Client.Client at 0x7f68274eb310>,
#  'maintainer': 'community_contribution',
#  'isJupyter': True,
#  'jupyterhubApiToken': 'MTcyLjI3LjAuMzo0NDNAODg0NmI4NWVkYzE0NDhhYTk2MTNlM2U5ZTkxNzI1YWU=',
#  'id': '1656003797urxMB',
#  'hpc': 'local_hpc'}

# %%
job.upload_executable_folder("git://hello_world")
# Out:
# <table>
# <thead>
# <tr><th style="text-align:left">id             </th><th style="text-align:left">slurmId  </th><th style="text-align:left">hpc      </th><th style="text-align:left">executableFolder      </th><th style="text-align:left">dataFolder  </th><th style="text-align:left">resultFolder  </th><th style="text-align:left">param  </th><th style="text-align:left">slurm  </th><th style="text-align:left">userId              </th><th style="text-align:left">maintainer            </th><th style="text-align:left">createdAt  </th></tr>
# </thead>
# <tbody>
# ...

# %%
job.set(executableFolder="git://hello_world")
# Out:
# <table>
# <thead>
# <tr><th style="text-align:left">id             </th><th style="text-align:left">slurmId  </th><th style="text-align:left">hpc      </th><th style="text-align:left">executableFolder  </th><th style="text-align:left">dataFolder  </th><th style="text-align:left">resultFolder  </th><th style="text-align:left">param  </th><th style="text-align:left">slurm  </th><th style="text-align:left">userId              </th><th style="text-align:left">maintainer            </th><th style="text-align:left">createdAt  </th></tr>
# </thead>
# <tbody>
# ...

# %%
job.submit()
# Out:
# ✅ job submitted
# <table>
# <thead>
# <tr><th style="text-align:left">id             </th><th style="text-align:left">slurmId  </th><th style="text-align:left">hpc      </th><th style="text-align:left">executableFolder  </th><th style="text-align:left">dataFolder  </th><th style="text-align:left">resultFolder  </th><th style="text-align:left">param  </th><th style="text-align:left">slurm  </th><th style="text-align:left">userId              </th><th style="text-align:left">maintainer            </th><th style="text-align:left">createdAt  </th></tr>
# </thead>
# <tbody>
# ...

# %%
job.events()
# Out:
# 📮 Job ID: 1656003797urxMB
# 🤖 Slurm ID: 34
# <table>
# <thead>
# <tr><th>types         </th><th>message                                                                            </th><th>time  </th></tr>
# </thead>
# <tbody>
# <tr><td>JOB_QUEUED    </td><td>job [1656003797urxMB] is queued, waiting for registration                          </td><td>      </td></tr>
# <tr><td>JOB_REGISTERED</td><td>job [1656003797urxMB] is registered with the supervisor, waiting for initialization</td><td>      </td></tr>
# <tr><td>JOB_REGISTERED</td><td>SSH Connection is working                                                          </td><td>      </td></tr>
# <tr><td>JOB_INIT      </td><td>job [1656003797urxMB] is initialized, waiting for job completion                   </td><td>      </td></tr>
# <tr><td>JOB_REGISTERED</td><td>SSH Connection is working                                                          </td><td>      </td></tr>
# ...

# %%
job.logs()
# Out:
# 📮 Job ID: 1656003797urxMB
# 🤖 Slurm ID: 34
# <table>
# <thead>
# <tr><th>message  </th><th>time  </th></tr>
# </thead>
# <tbody>
# <tr><td style='text-align:left'>INFO:    Converting SIF file to temporary sandbox...
# FATAL:   while extracting /home/user/simages/python.sif: root filesystem extraction failed: extract command failed: ERROR  : Failed to create user namespace: not allowed to create user namespace
# : exit status 1
# INFO:    Converting SIF file to temporary sandbox...
# FATAL:   while extracting /home/user/simages/python.sif: root filesystem extraction failed: extract command failed: ERROR  : Failed to create user namespace: not allowed...[download for full log]          </td><td style='text-align:left'>      </td></tr>
# </tbody>
# </table>
